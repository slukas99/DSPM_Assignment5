# %% [markdown]
# ---
#
# # DS400: Assignment IV (Python)
#
# ##### Lukas Schick (Student ID: 6291976)
# ##### January 13th, 2022

# %%
import numpy as np
import pandas as pd
import requests
import time
from API_key_A5 import discoveryapi_key
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Exercise 7

# %%
res = requests.get('https://app.ticketmaster.com/discovery/v2/venues?', 
             params = {"apikey" : discoveryapi_key,
                       "countryCode" : "DE"}).json()

# %% [markdown]
# The resulting list gives information on the returned venues, a specific venue can be accessed by appending `_embedded`$venues[[x]] to the content object. In this way, information on a specific venue, like its name, address or city can be accessed. There is also additional information on the number of results per page, the number of pages, total results and the current page number and more.

# %% [markdown]
# ## Exercise 8

# %%
#initialize empty df for total results
venues = pd.DataFrame({'name' : [],
                       'city' : [],
                       'postalCode' : [],
                       'address' : [],
                       'url' : [],
                       'longitude' : [],
                       'latitude' : []})

# %%
for i in range(0, res['page']['size']):
    try:
        name = res['_embedded']['venues'][i]['name']
    except:
        name = None
    try: 
        city = res['_embedded']['venues'][i]['city']['name']
    except:
        city = None
    try:
        postalCode = res['_embedded']['venues'][i]['postalCode']
    except:
        postalCode = None
    try:
        address = res['_embedded']['venues'][i]['address']['line1']
    except:
        address = None
    try:
        url = res['_embedded']['venues'][i]['url']
    except:
        url = None
    try:
        longitude = res['_embedded']['venues'][i]['location']['longitude']
    except:
        longitude = None
    try:
        latitude = res['_embedded']['venues'][i]['location']['latitude']
    except:
        latitude = None
    venues = venues.append({'name': name, 'city': city, 'postalCode': postalCode, 'address': address,
                       'url' : url, 'longitude' : longitude, 'latitude': latitude}, ignore_index=True)

# %%
venues
# Out:
#                              name             city postalCode  \
# 0                       Gruenspan          Hamburg      22767
# 1               Huxleys Neue Welt           Berlin      10967
# 2                  various venues           Bremen      28195
# 3                   Virtual Event        Worldwide       None
# 4           Ev. St. Jacobi Kirche     Sangerhausen      06526
# 5             Evangelische Kirche           Senden      48308
# 6                       HDI Arena         Hannover       None
# 7                         Arsenal           Berlin      10785
# 8       Freilichtbühne Heppenheim       Heppenheim      64646
# 9                Schlosswallhalle        Osnabrück      49074
# 10               Metropol Theater           Vechta      49377
# 11        RÖDERMARK - Kulturhalle        Rödermark      63322
# 12                           3922          Tambach      96479
# 13                Nibelungenhalle         Walldürn      74731
# 14            St. Johannis Kirche         Würzburg      97070
# 15                   filmkunst 66           Berlin      10623
# 16  Congress Centrum (Europasaal)        Böblingen      71032
# 17              Sauerland Theater         Arnsberg      59821
# 18               Hebbel am Ufer 1           Berlin      10963
# 19                     Roots Club  Mönchengladbach      41061
#
#                              address  \
# 0                 Grosse Freiheit 58
# 1               Hasenheide 107 – 113
# 2                               None
# 3                               None
# 4                         Marktplatz
# 5                    Steverstrasse 5
# 6               Robert-Enke-Straße 1
# 7                Potsdamer Strasse 2
# 8                 Oberhalb der Stadt
# 9                     Schlosswall 10
# 10                 Kolpingstrasse 27
# 11              Dieburger Strasse 27
# 12  Schlossinnenhof | Schlossallee 1
# 13                Theodor Heuss Ring
# 14                 Hofstallstrasse 5
# 15               Bleibtreustrasse 12
# 16                    Ida Ehre Platz
# 17                        Feauxweg 9
# 18              Stresemannstrasse 29
# 19            Aachener Strasse 21-23
#
#                                                   url longitude   latitude
# 0             http://www.ticketmaster.de/venue/287155  9.958075  53.551885
# 1             http://www.ticketmaster.de/venue/286842  13.42138  52.486391
# 2   https://www.ticketmaster.de/venue/diverse-loca...   8.80719   53.07574
# 3   https://www.ticketmaster.de/venue/virtuelles-e...      10.0       50.0
# 4             http://www.ticketmaster.de/venue/290061      None       None
# 5             http://www.ticketmaster.de/venue/290066      None       None
# 6             http://www.ticketmaster.de/venue/461692   9.73371  52.361993
# 7             http://www.ticketmaster.de/venue/290646      None       None
# 8             http://www.ticketmaster.de/venue/290639      None       None
# 9             http://www.ticketmaster.de/venue/290630      None       None
# 10            http://www.ticketmaster.de/venue/290631      None       None
# 11            http://www.ticketmaster.de/venue/290649      None       None
# 12            http://www.ticketmaster.de/venue/290642      None       None
# 13            http://www.ticketmaster.de/venue/290653      None       None
# 14            http://www.ticketmaster.de/venue/290650      None       None
# 15            http://www.ticketmaster.de/venue/290643      None       None
# 16            http://www.ticketmaster.de/venue/290622      None       None
# 17            http://www.ticketmaster.de/venue/290621      None       None
# 18            http://www.ticketmaster.de/venue/290635      None       None
# 19            http://www.ticketmaster.de/venue/290659      None       None

# %% [markdown]
# ## Exercise 9

# %%
num_pages = res['page']['totalPages']

#initialize empty df for total results
venues = pd.DataFrame({'name' : [],
                       'city' : [],
                       'postalCode' : [],
                       'address' : [],
                       'url' : [],
                       'longitude' : [],
                       'latitude' : []})

# %%
for j in range(0,num_pages):
    #sleep for 0.2 seconds to relieve stress from site
    time.sleep(0.2)
    
    res = requests.get('https://app.ticketmaster.com/discovery/v2/venues?', 
             params = {"apikey" : discoveryapi_key,
                       "countryCode" : "DE",
                       "page" : j}).json()
    
    
    
    try:
        for i in range(0, len(res['_embedded']['venues'])):
            try:
                name = res['_embedded']['venues'][i]['name']
            except:
                name = None
            try: 
                city = res['_embedded']['venues'][i]['city']['name']
            except:
                city = None
            try:
                postalCode = res['_embedded']['venues'][i]['postalCode']
            except:
                postalCode = None
            try:
                address = res['_embedded']['venues'][i]['address']['line1']
            except:
                address = None
            try:
                url = res['_embedded']['venues'][i]['url']
            except:
                url = None
            try:
                longitude = res['_embedded']['venues'][i]['location']['longitude']
            except:
                longitude = None
            try:
                latitude = res['_embedded']['venues'][i]['location']['latitude']
            except:
                latitude = None
            venues = venues.append({'name': name, 'city': city, 'postalCode': postalCode, 'address': address,
                               'url' : url, 'longitude' : longitude, 'latitude': latitude}, ignore_index=True)
    except:
        pass

# %%
venues.head(10)
# Out:
#                         name          city postalCode               address  \
# 0                  Gruenspan       Hamburg      22767    Grosse Freiheit 58
# 1          Huxleys Neue Welt        Berlin      10967  Hasenheide 107 – 113
# 2             various venues        Bremen      28195                  None
# 3              Virtual Event     Worldwide       None                  None
# 4      Ev. St. Jacobi Kirche  Sangerhausen      06526            Marktplatz
# 5        Evangelische Kirche        Senden      48308       Steverstrasse 5
# 6                  HDI Arena      Hannover       None  Robert-Enke-Straße 1
# 7                    Arsenal        Berlin      10785   Potsdamer Strasse 2
# 8  Freilichtbühne Heppenheim    Heppenheim      64646    Oberhalb der Stadt
# 9           Schlosswallhalle     Osnabrück      49074        Schlosswall 10
#
#                                                  url longitude   latitude
# 0            http://www.ticketmaster.de/venue/287155  9.958075  53.551885
# 1            http://www.ticketmaster.de/venue/286842  13.42138  52.486391
# 2  https://www.ticketmaster.de/venue/diverse-loca...   8.80719   53.07574
# 3  https://www.ticketmaster.de/venue/virtuelles-e...      10.0       50.0
# 4            http://www.ticketmaster.de/venue/290061      None       None
# 5            http://www.ticketmaster.de/venue/290066      None       None
# 6            http://www.ticketmaster.de/venue/461692   9.73371  52.361993
# 7            http://www.ticketmaster.de/venue/290646      None       None
# 8            http://www.ticketmaster.de/venue/290639      None       None
# 9            http://www.ticketmaster.de/venue/290630      None       None

# %%
np.shape(venues)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [103], line 1
# ----> 1 shape(venues)
#
# NameError: name 'shape' is not defined
