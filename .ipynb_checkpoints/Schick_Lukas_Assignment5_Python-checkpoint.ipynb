# %% [markdown]
# ---
#
# # DS400: Assignment IV (Python)
#
# ##### Lukas Schick (Student ID: 6291976)
# ##### January 24th, 2022

# %%
#import needed packages
import numpy as np
import pandas as pd
import requests
import time
from API_key_A5 import discoveryapi_key
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Exercises 1-6
#
# Set up GitHub repository and get Ticketmaster API key, not no coding needed.

# %% [markdown]
# # Exercise 7

# %%
#perform get request of ticketmaster site to get all venues in Germany
res = requests.get('https://app.ticketmaster.com/discovery/v2/venues?', 
             params = {"apikey" : discoveryapi_key,
                       "countryCode" : "DE"}).json()

# %% [markdown]
# The resulting list gives information on the returned venues, a specific venue can be accessed by appending `_embedded`$venues[[x]] to the content object. In this way, information on a specific venue, like its name, address or city can be accessed. There is also additional information on the number of results per page, the number of pages, total results and the current page number and more.

# %% [markdown]
# ## Exercise 8

# %%
#initialize empty df for total results
venues = pd.DataFrame({'name' : [],
                       'city' : [],
                       'postalCode' : [],
                       'address' : [],
                       'url' : [],
                       'longitude' : [],
                       'latitude' : []})

# %%
#for each result on the page, do the following
for i in range(0, res['page']['size']):
    #get name, city, postalCode etc. if they are available, otherwise use None
    try:
        name = res['_embedded']['venues'][i]['name']
    except:
        name = None
    try: 
        city = res['_embedded']['venues'][i]['city']['name']
    except:
        city = None
    try:
        postalCode = res['_embedded']['venues'][i]['postalCode']
    except:
        postalCode = None
    try:
        address = res['_embedded']['venues'][i]['address']['line1']
    except:
        address = None
    try:
        url = res['_embedded']['venues'][i]['url']
    except:
        url = None
    try:
        longitude = res['_embedded']['venues'][i]['location']['longitude']
    except:
        longitude = None
    try:
        latitude = res['_embedded']['venues'][i]['location']['latitude']
    except:
        latitude = None
    #append latest result to dataframe
    venues = venues.append({'name': name, 'city': city, 'postalCode': postalCode, 'address': address,
                       'url' : url, 'longitude' : longitude, 'latitude': latitude}, ignore_index=True)

# %%
venues
# Out:
#                              name             city postalCode  \
# 0                       Gruenspan          Hamburg      22767
# 1               Huxleys Neue Welt           Berlin      10967
# 2                   Virtual Event        Worldwide       None
# 3           Ev. St. Jacobi Kirche     Sangerhausen      06526
# 4             Evangelische Kirche           Senden      48308
# 5                       HDI Arena         Hannover       None
# 6                         Arsenal           Berlin      10785
# 7       Freilichtbühne Heppenheim       Heppenheim      64646
# 8                Schlosswallhalle        Osnabrück      49074
# 9                Metropol Theater           Vechta      49377
# 10        RÖDERMARK - Kulturhalle        Rödermark      63322
# 11                           3922          Tambach      96479
# 12                Nibelungenhalle         Walldürn      74731
# 13            St. Johannis Kirche         Würzburg      97070
# 14                   filmkunst 66           Berlin      10623
# 15  Congress Centrum (Europasaal)        Böblingen      71032
# 16              Sauerland Theater         Arnsberg      59821
# 17               Hebbel am Ufer 1           Berlin      10963
# 18                     Roots Club  Mönchengladbach      41061
# 19               Alte Feuerwache            Berlin      12439
#
#                              address  \
# 0                 Grosse Freiheit 58
# 1               Hasenheide 107 – 113
# 2                               None
# 3                         Marktplatz
# 4                    Steverstrasse 5
# 5               Robert-Enke-Straße 1
# 6                Potsdamer Strasse 2
# 7                 Oberhalb der Stadt
# 8                     Schlosswall 10
# 9                  Kolpingstrasse 27
# 10              Dieburger Strasse 27
# 11  Schlossinnenhof | Schlossallee 1
# 12                Theodor Heuss Ring
# 13                 Hofstallstrasse 5
# 14               Bleibtreustrasse 12
# 15                    Ida Ehre Platz
# 16                        Feauxweg 9
# 17              Stresemannstrasse 29
# 18            Aachener Strasse 21-23
# 19        Michael-Brückner-Strasse 9
#
#                                                   url longitude   latitude
# 0             http://www.ticketmaster.de/venue/287155  9.958075  53.551885
# 1             http://www.ticketmaster.de/venue/286842  13.42138  52.486391
# 2   https://www.ticketmaster.de/venue/virtuelles-e...      10.0       50.0
# 3             http://www.ticketmaster.de/venue/290061      None       None
# 4             http://www.ticketmaster.de/venue/290066      None       None
# 5             http://www.ticketmaster.de/venue/461692   9.73371  52.361993
# 6             http://www.ticketmaster.de/venue/290646      None       None
# 7             http://www.ticketmaster.de/venue/290639      None       None
# 8             http://www.ticketmaster.de/venue/290630      None       None
# 9             http://www.ticketmaster.de/venue/290631      None       None
# 10            http://www.ticketmaster.de/venue/290649      None       None
# 11            http://www.ticketmaster.de/venue/290642      None       None
# 12            http://www.ticketmaster.de/venue/290653      None       None
# 13            http://www.ticketmaster.de/venue/290650      None       None
# 14            http://www.ticketmaster.de/venue/290643      None       None
# 15            http://www.ticketmaster.de/venue/290622      None       None
# 16            http://www.ticketmaster.de/venue/290621      None       None
# 17            http://www.ticketmaster.de/venue/290635      None       None
# 18            http://www.ticketmaster.de/venue/290659      None       None
# 19            http://www.ticketmaster.de/venue/290658      None       None

# %% [markdown]
# ## Exercise 9

# %%
#perform get request of ticketmaster site to get all venues in Germany
res = requests.get('https://app.ticketmaster.com/discovery/v2/venues?', 
             params = {"apikey" : discoveryapi_key,
                       "countryCode" : "DE"}).json()

# %%
#compute total number of result pages
num_pages = res['page']['totalPages']

#initialize empty df for total results
venues = pd.DataFrame({'name' : [],
                       'city' : [],
                       'postalCode' : [],
                       'address' : [],
                       'url' : [],
                       'longitude' : [],
                       'latitude' : []})

# %%
#for every results page, do the following
for j in range(0,num_pages):
    
    #sleep for 0.2 seconds to relieve stress from site
    time.sleep(0.2)
    
    #perform get request of ticketmaster site to get all venues in Germany
    res = requests.get('https://app.ticketmaster.com/discovery/v2/venues?', 
             params = {"apikey" : discoveryapi_key,
                       "countryCode" : "DE",
                       "page" : j}).json()
    
    
    #check if there are results on the page (sometimes due to connection errors, no results will show up)
    try:
        #for each result on the page, do the following
        for i in range(0, len(res['_embedded']['venues'])):
            #get name, city, postalCode etc. if they are available, otherwise use None
            try:
                name = res['_embedded']['venues'][i]['name']
            except:
                name = None
            try: 
                city = res['_embedded']['venues'][i]['city']['name']
            except:
                city = None
            try:
                postalCode = res['_embedded']['venues'][i]['postalCode']
            except:
                postalCode = None
            try:
                address = res['_embedded']['venues'][i]['address']['line1']
            except:
                address = None
            try:
                url = res['_embedded']['venues'][i]['url']
            except:
                url = None
            try:
                longitude = res['_embedded']['venues'][i]['location']['longitude']
            except:
                longitude = None
            try:
                latitude = res['_embedded']['venues'][i]['location']['latitude']
            except:
                latitude = None
            venues = venues.append({'name': name, 'city': city, 'postalCode': postalCode, 'address': address,
                               'url' : url, 'longitude' : longitude, 'latitude': latitude}, ignore_index=True)
    #if results for this page can't be loaded due to a connection error, pass
    except:
        pass

# %%
#print first ten results
venues.head(10)
# Out:
#                         name          city postalCode               address  \
# 0                  Gruenspan       Hamburg      22767    Grosse Freiheit 58
# 1          Huxleys Neue Welt        Berlin      10967  Hasenheide 107 – 113
# 2              Virtual Event     Worldwide       None                  None
# 3      Ev. St. Jacobi Kirche  Sangerhausen      06526            Marktplatz
# 4        Evangelische Kirche        Senden      48308       Steverstrasse 5
# 5                  HDI Arena      Hannover       None  Robert-Enke-Straße 1
# 6                    Arsenal        Berlin      10785   Potsdamer Strasse 2
# 7  Freilichtbühne Heppenheim    Heppenheim      64646    Oberhalb der Stadt
# 8           Schlosswallhalle     Osnabrück      49074        Schlosswall 10
# 9           Metropol Theater        Vechta      49377     Kolpingstrasse 27
#
#                                                  url longitude   latitude
# 0            http://www.ticketmaster.de/venue/287155  9.958075  53.551885
# 1            http://www.ticketmaster.de/venue/286842  13.42138  52.486391
# 2  https://www.ticketmaster.de/venue/virtuelles-e...      10.0       50.0
# 3            http://www.ticketmaster.de/venue/290061      None       None
# 4            http://www.ticketmaster.de/venue/290066      None       None
# 5            http://www.ticketmaster.de/venue/461692   9.73371  52.361993
# 6            http://www.ticketmaster.de/venue/290646      None       None
# 7            http://www.ticketmaster.de/venue/290639      None       None
# 8            http://www.ticketmaster.de/venue/290630      None       None
# 9            http://www.ticketmaster.de/venue/290631      None       None

# %%
#print shape
np.shape(venues)
# Out:
# (4565, 7)

# %% [markdown]
# Note on the dimensions of venues_total: Because of a SpikeArrestViolation, the results of some pages are not available, even though the suggested pause of 0.2s between requests is included. This means that for any given run of the two code chunks above, the number of rows of the total results is not always the whole 4745, but may be up to 80 results less. (this means results for 4 pages are not included)

# %% [markdown]
# ## Exercises 10 + 11

# %%
#drop NAs from longitude and latitude data
longitude = pd.to_numeric(venues["longitude"].dropna())
latitude = pd.to_numeric(venues["latitude"].dropna())

# %%
#make sure to only use data within the specified country bounds
longitude = longitude.loc[lambda x : (x > 5.866) & (x < 15.042)]

# %%
latitude = latitude.loc[lambda x : (x > 47.270) & (x < 55.059)]

# %%
#plot the venues on a map of Germany
import geopandas as gpd
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(7,7))
ax.plot(longitude, latitude, 'ro')
# get a base map of Germany
map = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres")) 
map = map[map.name == "Germany"]
# plot the map
map.plot(ax = ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Exercise 12

# %%
#perform get request of ticketmaster site to get all venues in France
res = requests.get('https://app.ticketmaster.com/discovery/v2/venues?', 
             params = {"apikey" : discoveryapi_key,
                       "countryCode" : "FR"}).json()

# %%
#get total number of result pages
num_pages = res['page']['totalPages']

#initialize empty df for total results
venues = pd.DataFrame({'name' : [],
                       'city' : [],
                       'postalCode' : [],
                       'address' : [],
                       'url' : [],
                       'longitude' : [],
                       'latitude' : []})

# %%
#for every result page, do the following
for j in range(0,num_pages):
    #sleep for 0.2 seconds to relieve stress from site
    time.sleep(0.2)
    
    #perform get request of ticketmaster site to get all venues in France
    res = requests.get('https://app.ticketmaster.com/discovery/v2/venues?', 
             params = {"apikey" : discoveryapi_key,
                       "countryCode" : "FR",
                       "page" : j}).json()
    
    
    #check if there are results on the page (sometimes due to connection errors, no results will show up)
    try:
        #for every result on the page, do the following
        for i in range(0, len(res['_embedded']['venues'])):
            #get name, city, postalCode etc. if they are available, otherwise use None
            try:
                name = res['_embedded']['venues'][i]['name']
            except:
                name = None
            try: 
                city = res['_embedded']['venues'][i]['city']['name']
            except:
                city = None
            try:
                postalCode = res['_embedded']['venues'][i]['postalCode']
            except:
                postalCode = None
            try:
                address = res['_embedded']['venues'][i]['address']['line1']
            except:
                address = None
            try:
                url = res['_embedded']['venues'][i]['url']
            except:
                url = None
            try:
                longitude = res['_embedded']['venues'][i]['location']['longitude']
            except:
                longitude = None
            try:
                latitude = res['_embedded']['venues'][i]['location']['latitude']
            except:
                latitude = None
                
            #append latest result to dataframe
            venues = venues.append({'name': name, 'city': city, 'postalCode': postalCode, 'address': address,
                               'url' : url, 'longitude' : longitude, 'latitude': latitude}, ignore_index=True)
    #if results for this page can't be loaded due to a connection error, pass
    except:
        pass

# %%
#print first ten results
venues.head(10)
# Out:
#                      name                      city postalCode  \
# 0             Le Trabendo                     Paris      75019
# 1    Stade Chaban-Delmas                   Bordeaux      33000
# 2       Accorhotels Arena                     Paris      75012
# 3  Paris La Defense Arena                     Paris    BT7 9HJ
# 4                  FRANCE  Madeleine-Sous-Montreuil      62170
# 5                  FRANCE                    Menton      06500
# 6                  FRANCE                     Paris      75011
# 7                  FRANCE                     Paris      75008
# 8            Stade Bayard      Charleville-Mézières      08000
# 9         Départ de Lille                     Lille      59000
#
#                                        address  \
# 0  Parc de la Villette, 211 Avenue Jean Jaurès
# 1                               Place Johnston
# 2                         8 Boulevard de Bercy
# 3                        99 Jardins de l'Arche
# 4                       Rue de la Grenouillère
# 5                    30 avenue Aristide Briand
# 6                        129 avenue Parmentier
# 7                          25 avenue Montaigne
# 8                         Charleville-Mezieres
# 9                           Place Saint-Hubert
#
#                                                  url longitude    latitude
# 0                                               None   2.39026  48.8938489
# 1                                               None      None        None
# 2                                               None  2.378568   48.838721
# 3                                               None      None        None
# 4  https://www.ticketmaster.be/venue/france-madel...   1.75239   50.470086
# 5  https://www.ticketmaster.be/venue/france-mento...  7.527968   43.785885
# 6  https://www.ticketmaster.be/venue/france-paris...  2.371287   48.869354
# 7  https://www.ticketmaster.be/venue/france-paris...  2.304272   48.866208
# 8  https://www.ticketmaster.be/venue/stade-bayard...     4.715    49.76442
# 9  https://www.ticketmaster.be/venue/depart-de-li...   3.07082    50.63878

# %%
#print shape
np.shape(venues)
# Out:
# (93, 7)

# %%
#drop NAs from latitude and longitude
longitude = pd.to_numeric(venues["longitude"].dropna())
latitude = pd.to_numeric(venues["latitude"].dropna())

# %%
#only keep values within the specified country bounds
latitude = latitude.loc[lambda x : (x > 42.333) & (x < 51.083)]

# %%
#for longitude, see which indices remain for latitude, as a lot of longitude values are automatically 
#set to 0 when no data is available, which is within the bounds of France, but is not real data
longitude = longitude[longitude.index.isin(latitude.index)]

# %%
#check if some data still needs to be deleted according to the country bounds for longitude
longitude = longitude.loc[lambda x : (x > -4.783) & (x < 8.216)]

# %%
#plot the venues on a map of France
import geopandas as gpd
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(7,7))
ax.plot(longitude, latitude, 'ro')
# get a base map of Germany
map = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres")) 
map = map[map.name == "France"]
# plot the map
map.plot(ax = ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Proportions of the chart are different from R because French Guyana is included in the France map in the geopandas package.
